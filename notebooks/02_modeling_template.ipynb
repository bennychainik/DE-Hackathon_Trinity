# %% [markdown]
# # 02. Modeling & Evaluation
#
# **Goal:** Train baseline and advanced models, evaluate performance.

# %%
import pandas as pd
import numpy as np
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

from src import preprocessing, models, evaluation, interpretability

# %% [markdown]
# ## 1. Load & Preprocess Data

# %%
# df = pd.read_csv('../data/raw/train.csv')
prep = preprocessing.Preprocessor()

# X_train, X_test, y_train, y_test = prep.split_data(df, 'target')

# %% [markdown]
# ## 2. Baseline Model

# %%
factory = models.ModelFactory()
# model = factory.get_model('logistic_regression')
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)

# %% [markdown]
# ## 3. Evaluation

# %%
# metrics = evaluation.get_classification_metrics(y_test, y_pred)
# print(metrics)
# evaluation.plot_confusion_matrix(y_test, y_pred)

# %% [markdown]
# ## 4. Advanced Models (XGBoost/LightGBM)

# %%
# xgb_model = factory.get_model('xgboost')
# xgb_model.fit(X_train, y_train)

# %% [markdown]
# ## 5. Interpretability

# %%
# interpretability.plot_feature_importance(xgb_model, X_train.columns)
