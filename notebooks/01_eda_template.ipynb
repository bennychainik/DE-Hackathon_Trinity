# %% [markdown]
# # 01. Exploratory Data Analysis (EDA)
#
# **Goal:** Understand the data structure, quality, and relationships.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path
sys.path.append(os.path.abspath(os.path.join('..')))

from src import eda, utils

# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
# df = pd.read_csv('../data/raw/train.csv')
# df.head()

# %% [markdown]
# ## 2. Basic Info & Missing Values

# %%
# eda.get_basic_stats(df)
# eda.check_missing_values(df)

# %% [markdown]
# ## 3. Distributions

# %%
# eda.plot_distribution(df, 'target_column')

# %% [markdown]
# ## 4. Correlations

# %%
# eda.plot_correlation_heatmap(df)
